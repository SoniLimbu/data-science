# %% [markdown]
# For loop:
# A for loop is used to iterate over elements in a sequence .
# - it runs a block of code repeatdely as long as the condition is true
#
# syntax:
# for iterable_variable in variables:
#     print()

# %%
# iterate over the string;
name ="Nishan"
for i in name:
    print(i)
# Out:
# N
# i
# s
# h
# a
# n

# %%
name ="ria"
for character in name:
    print("hello")
# Out:
# hello
# hello
# hello

# %%
#iterate over the list 
languages = ["English","python","C++"]
for i in languages:
    print(i,end=" ")
# Out:
# English python C++

# %% [markdown]
# range() sequence :
# for iterable_variable in range(start,stop):
#  --block of code
#
#  note : stop range is omitted

# %%
for item in range(1,5):
    print(item)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Beginner Level
# Q1. Grocery Bill Calculator (Features + Dataset)
# Ask the user for the price and quantity of 3 items. Store each item as a dictionary in a list. Calculate the total bill, apply a 10% discount if total exceeds $50, and print the final amount.

# %%
items = []
for i in range(3):
    name = input(f"Enter name of item {i+1}: ")
    price = float(input(f"Enter price of {name}: "))
    qty = int(input(f"Enter quantity of {name}: "))
    items.append({"name": name, "price": price, "quantity": qty})

total = 0
for item in items:
    total += item["price"] * item["quantity"]

if total > 50:
    discount = total * 0.10
    total -= discount
    print(f"Discount applied: ${discount:.2f}")

print(f"Final bill: ${total:.2f}")

# %%
numbers = [12,45,7,89,92,23,56]
largest = numbers[0]
for i in numbers:
    if i > largest:
        largest =i

print(largest)
# Out:
# 92

# %%
numbers =[12,7,58,96,54,69,70]
even=[]
odd=[]

for i in numbers:
    if i%2==0:
        even.append(i)
    else:
        odd.append(i)
        
print(f"even numbers Are:{even}")
print(f"odd numbers are:{odd}")
# Out:
# even numbers Are:[12, 58, 96, 54, 70]
# odd numbers are:[7, 69]

# %%
#the sum of all nautaral numbers from 1 to user input number
number = int(input("enter the number :"))
total =0
for i in range(1,number+1):
    total = total + i
print(f"sum is {total}")
# Out:
# sum is 15

# %% [markdown]
# Sum of number unitil user enter 0

# %%
total = 0
for i in range(1000):
    num = int(input("enter the number:"))
    if num == 0:
        break #stop early
    total = total + num 

print(f"total of {i} numbers  is {total }")
# Out:
# total of 4 numbers  is 28

# %%
days = ['Sun','Mon','Tue','Wed','Thu','Fri','Sat']

steps =[]

for day in days:
    s= float(input(f"steps of user on {day}"))
    steps.append(s)
    
    
total = sum(steps)
mean=total/ len(steps)
highest_day = days[steps.index(max(steps))]
print(f"total is {total}")
print(f'mean is {mean}')
print(f"Min:{min(steps)},Max:{max(steps)}")
print(f"highest day:{highest_day}")
# Out:
# total is 27430.0
# mean is 3918.5714285714284
# Min:10.0,Max:10000.0
# highest day:Sat
