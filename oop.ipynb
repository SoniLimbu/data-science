# %% [markdown]
# #OOP - object oriented programming languages
# Everything is an object
# python allows to create a customs classes
# 1. class = will define attributes and behaviour -blueprint of an object.
# 2. object - it os an instance of class
#
# there are 4 pillars in  OOP -
# Inheritance
# polymorphism
# Encapsulation
# data abstraction
#
# steps in creating an class and object:
# 1. define a class
# 2. create objects from the class
#
# class - keyword
# syntax:
# class keyword:
#     variable are attributes
#     functions are called methods

# %%
#creating a class 
class person:

  pass

person1 = person()
person2 = person()

# %% [markdown]
# when u define a method inside a class u need to write self as the first parameter or arguments
# self -represent the specific instance of a class
# self - this particular object(pointer)

# %%
class student:
    def check_pass_fail(self):
        
        if self.score >=40:
           return True
        else:
            return False

std1 = student()
std1.score = 90
std1.check_pass_fail()

'''
here self represents the current object that is to be calling thenwhen u create a object and then 
    '''
# Out:
# '\nhere self represents the current object that is to be calling thenwhen u create a object and then \n    '

# %% [markdown]
# #adding attributes in a proper way
# constructor - it is a special type of method used to intialize the object of the class  it will be executed automatically, whenever an object is created.
# -declare and intialize instance variable
# _int_() -method for defining the constructor

# %%
class Test:
    def __init__(self):
         print("Hello, I am here")


      
test1 = Test()
test2 = Test()
# Out:
# Hello, I am here
# Hello, I am here

# %%
class student:
    def _init_(self,name,score):
        self.name=name 
        self.score = score
        
def  check_pass_fail(self):
        if self.score >=40:
            return True 
        else:
            return False
student1 = student ("hary", 85)

did_pass = student1.check_pass_fail()
print (f"Did {student1.name} pass?", did_pass)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       7         if self.score >=40:
#       8             return True
#       9         else:
#      10             return False
# ---> 11 student1 = student("hary", 85)
#      12
#      13 did_pass = student1.check_pass_fail()
#      14 print (f"Did {student1.name} pass?", did_pass)
#
# TypeError: student() takes no arguments

# %%
class Student:
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
        self.total = 0
        self.average = 0
        self.grade =" "
    
    def calculate_total_average(self):
        self.total = sum(self.marks)
        self.average = self.total / len(self.marks)
        
    def assign_grade(self):
        if self.average >=90:
            self.grade = "A"
        elif self.average >=80:
            self.grade ="B"
        elif self.average >=70:
            self.grade ="C"
        elif self.average >= 60:
            self.grade = "D"
        else:
            self.grade ="F"
            
            
    def show_result(self):
        print(f"Student name is {self.name}")
        print(f"Student marks is {self.marks}")
        print(f"Student total marks is {self.total}")
        print(f"Student Average marks is {self.average:.2f}")
        print(f"Grade is :{self.grade}")
        
        
name = input("enter the student name")
marks=[]
for i in range(1,4):
    mark=float(input("enter marks of subject"))
    marks.append(mark)
    
student = Student(name,marks)
student.calculate_total_average()
student.assign_grade()
student.show_result()
# Out:
# Student name is soni
# Student marks is [20.0, 190.0, 200.0]
# Student total marks is 410.0
# Student Average marks is 136.67
# Grade is :A

# %% [markdown]
# # create a class circle that calcualtes the area of circle

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius


c = Circle(5)

print(c.area())
# Out:
# 78.5

# %%
class Dog:
    def sound(self):
        print('Dog barks')
class Cat:
    def sound(self):
        print('cat meows') 
        
def make_sound(self):  # polymorphic function 
    self.sound()

d =Dog()
c=Cat()
make_sound (d)
make_sound( c)
# Out:
# Dog barks
# cat meows

# %% [markdown]
# inheritance:
# 1. single parent
# 2. single child

# %%
class Movie:
    def _init_(self,title):
        self.title =title
    
    def display(self):
        print("Movies is", self.title)



class ActionMovies(Movie):
    def show_genre(self):
        print("Genre is action")


movie1 = ActionMovies()
movie1.title = "Avenger End game"
movie1.display()
movie1.show_genre()
# Out:
# Movies is Avenger End game
# Genre is action

# %%
class classifer:
    def predict(self,data):
        print("making predcition")

class KNN(classifer):
    def show_model(self):
        print("using KNN")

model =KNN()
model.predict([10,20])
model.show_model()
# Out:
# making predcition
# using KNN

# %% [markdown]
# Create a parent class MLmodel with model name and accuracy and a method checkperformace that prints whether the model has a good performance.
# Then again create a child class knn with additional attribute k
# create a method show_details in knn that display the model name accuracy and value of k

# %%
class MLmodel:
    def __init__(self, model_name, accuracy):
        self.model_name = model_name
        self.accuracy = accuracy

    def checkperformace(self):
        if self.accuracy >= 0.80:
            print("The model has good performance.")
        else:
            print("The model performance needs improvement.")


class knn(MLmodel):
    def __init__(self, model_name, accuracy, k):
        super().__init__(model_name, accuracy)
        self.k = k

    def show_details(self):
        print(f"Model name: {self.model_name}")
        print(f"Accuracy: {self.accuracy:.2%}")
        print(f"Value of k: {self.k}")


knn_model = knn("K-Nearest Neighbors", 0.90, 5)
knn_model.show_details()
knn_model.checkperformace()
# Out:
# Model name: K-Nearest Neighbors
# Accuracy: 90.00%
# Value of k: 5
# The model has good performance.
