# %% [markdown]
# #OOP - object oriented programming languages
# Everything is an object
# python allows to create a customs classes
# 1. class = will define attributes and behaviour -blueprint of an object.
# 2. object - it os an instance of class
#
# there are 4 pillars in  OOP -
# Inheritance
# polymorphism
# Encapsulation
# data abstraction
#
# steps in creating an class and object:
# 1. define a class
# 2. create objects from the class
#
# class - keyword
# syntax:
# class keyword:
#     variable are attributes
#     functions are called methods

# %%
#creating a class 
class person:

  pass

person1 = person()
person2 = person()

# %% [markdown]
# when u define a method inside a class u need to write self as the first parameter or arguments
# self -represent the specific instance of a class
# self - this particular object(pointer)

# %%
class student:
    def check_pass_fail(self):
        
        if self.score >=40:
           return True
        else:
            return False

std1 = student()
std1.score = 90
std1.check_pass_fail()

'''
here self represents the current object that is to be calling thenwhen u create a object and then 
    '''
# Out:
# True
