# %%
# python programming 

Input and Output in python:
-print()

Input function:
input()
# Out:
#   Cell In[6], line 3
#     Input and Output in python:
#                               ^
# SyntaxError: invalid syntax

# %%
print(5)
print("python is programming language")

# %%
# Here, 5 is an integer number.
floating number = > decimal number
string -text
Integer and string data types - inbuilt functions
int , str ,float -keywords

# %%
Input functions 
input("what is your name?")
variables_  -store data that can be referenced and manipulated.
-naming convention

# %%
x = 5 
print(x)

# %%
x =5 
y = "Hello world"
print("The value of x is", x, "and The value of y is", y)

# %%
# Input function
variable_name = input("")  # string input
variable_name = input("")  # string input

# %%
name = input("Enter your name: ")
print(name)

# %%
# this is the comment section of the code  -single line comment

name = int(input("Enter the number : ")) #this is the section which takes input from the user and converts it into integer data type - inline comment
print(name)

"""
This is the code taking the user input and converting it into integer data type and printing the value of the variable name. - multiline comment
"""

# %%
number_1 = int(input("Enter the first number: "))
number_2 = int(input("Enter the second number: "))
sum = number_1 + number_2
difference = number_1 - number_2
product = number_1 * number_2
modulus = number_1 % number_2
floor_division = number_1 // number_2
print("The sum of the two numbers is:", sum)
print("The difference of the two numbers is:", difference)
print("The product of the two numbers is:", product)    
print("The modulus of the two numbers is:", modulus)
print("The floor division of the two numbers is:", floor_division)

# %%
x = 10
y = 12
print('x>y is', x > y)
print('x<y is', x < y)
print('x>=y is', x >= y)
print('x<=y is', x <= y)
print('x==y is', x == y)
print('x!=y is', x != y)
'''here the True and False are the boolean values which are the output of the comparison operators.'''

# %%
x = True 
y=False
print('x and y is', x and y)
print('x or y is', x or y)
print('not x is', not x)

'''
| = or operators
'''

# %%
# += means: x = x + 5
x += 5
print(x)

# %%
# Identity operators:
# `is` and `is not` check whether two values refer to the same object in memory.

# %% [markdown]
# x1 = 5
# y1 =5
# x2 = 'hello'
# y2 = 'Hello'
# print ('x1 is y1 is = ' x1 is y1)
# print('x1 is not y1 is =',x1 is not y1)

# %%
list -user defined data types
list are mutubale data types 
syntax:
[]-square brackets -it holds multiple data types

# %%
cart = ["apple", 10,20.5, True, 'B', [45]]
print(cart)
print(type(cart)) # type is an inbuilt function which is used to check the data type of the variable

# %% [markdown]
# Here , in the list the items are stored fron the index 0. (zero based indexing)

# %%
the_list=[1,2,3,4,5,6['apple']]
print(the_list)
print(the_list[0])
print(the_list[5])  #fetching the item from the list-list items  sets

# %% [markdown]
# Here,we had use the len(function)taking list an argument

# %%
language = ['python', 'java', 'c++', 'javascript', 'ruby']
print(len(language))

# %% [markdown]
# slicing of a list:
# : -slicing operator
# syntax: variable = list_name[start : end]

# %%
numbers = [1, 2, 3, 4, 5]
variables = numbers[2:5]
print(variables)
# Out:
# [3, 4, 5]

# %% [markdown]
# python list index will omit the end index.
# here, 2:5 i.e-it prints the item from the 2 nd index up to the 4 th index. it will never ever return the stop index.

# %%
number = [10,20,30,40,50]
variable = number[:4]
print(variable)
# Out:
# [10, 20, 30, 40]

# %%
languages = ["Python", "Java", "C++", "JavaScript"]
languages[1]='Python'
print(languages)
# Out:
# ['Python', 'Python', 'C++', 'JavaScript']

# %%
languages = ["Python", "Java", "C++", "JavaScript"]

del languages[1]
print(languages)
print(languages)
# Out:
# ['Python', 'C++', 'JavaScript']
# ['Python', 'C++', 'JavaScript']

# %%
del languages
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 del languages
#
# NameError: name 'languages' is not defined

# %%
print(language)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(language)
#
# NameError: name 'language' is not defined

# %%
#Append methods():
#-it is used to add an item to the end of the list.
#syntax :append ("")

# %%
colors = ['blue','green']
colors.append('red')
print(colors)
# Out:
# ['blue', 'green', 'red']

# %%
#extend()- it add all the items of one list to the end of another list.

# %%
animals = ['dog','cat']
numbers = [1, 2, 3]
animals.extend(numbers)
print(animals)
# Out:
# ['dog', 'cat', 1, 2, 3]

# %%
#insert () adding the items to the list at specific index  that takes the two arguments:
   # 1. index 
    #2. item to insert

# %%
animals = ['cat', 'dog', 'elephant']
animals.insert(1, 'tiger')  
print(animals)
# Out:
# ['cat', 'tiger', 'dog', 'elephant']

# %%
animals = []
print(animals)
# Out:
# []

# %%
animals= []
animals.append('dog')
print(animals)
animals.append('cat')
print(animals)
# Out:
# ['dog']
# ['dog', 'cat']

# %%
#Tuples:
# -immutable data types
#()

# %%
numbers1 = (10,20,30)
print(numbers1)
print(type(numbers1))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
numbers_1=(1)
print(numbers_1)
print(type(numbers_1))
# Out:
# 1
# <class 'int'>

# %%
numbers_1=(1,)
print(numbers_1)
print(type(numbers_1))
# Out:
# (1,)
# <class 'tuple'>

# %%
subjects = ('Math', 'Science')
subjects = ('Math', 'Science')
subjects = ('physics',)
print(subjects)
print(subjects)
# Out:
# ('physics',)
# ('physics',)

# %%
#Write a program to access and print a character from a string assing the snowpuercer string to a variable named movie
#Print the fourth character from the string

# %%
movie='Snowpiercer'
print(movie[3])
# Out:
# w

# %%
## Sets :It is collection of item.-unordered
#-unique
#-use{}

# %%
animals = {'dog', 'cat', 'elephant'}
print(type(animals))
print(animals)
# Out:
# <class 'set'>
# {'elephant', 'cat', 'dog'}

# %%
# creating an empty set

# %%
my_set = set()  # use the set(function)
print(my_set)
# Out:
# set()

# %%
#we will be using the add() function -inbuilt functions

# %%
#adding the items in the set:
numbers = {1, 2, 3}
numbers.add("true")
print(numbers)
# Out:
# {1, 2, 3, 'true'}

# %%
my_set = set()
my_set.add(1)
my_set.add(2)
my_set.add(3)
my_set.add("ram")
print(my_set)
# Out:
# {'ram', 1, 2, 3}

# %%
#update set()
#-we use the update() method - it is used tto update a set with items of other collection type such as list,tuples,or other colllection types.

# %%
book = {"python","c++",5}
wild_animals = {"tiger", "lion", "elephant"}
book.update(wild_animals)
print(book)
# Out:
# {'lion', 5, 'elephant', 'tiger', 'python', 'c++'}

# %% [markdown]
# Create an empty set using the set() function and assign it to the numbers variable .get an ineter input from the user and assign that value to number variable.
# add number to the numbers set using the set method
# print the numbers set output.

# %%
numbers = set()
number = input("Enter a number: ")
numbers.add(number)
print(numbers)

# %%
## removing the item from the set discard() -method -specific items

# %%
animals = {'tiger',"cat"}
animals.discard('tiger')
print(animals)

# %%
## Dictionaries 
#-each item of the dictionary is a key/value pair
#{ 
    #' key':"value",
   # --
#}

# %%
person ={
    'name':"Nishan",
    'age': 25,
    'address':'Jhapa'
         }
print(person)
print(type(person))
print(len(person))


#access dictionary values
print(person['age'])

#updating the value of key 
person['name']="Shyam"

print("changed in the name",person)

#adding the items in dicitonary 

person['city '] ="Birtamode"
print(person)

# delete the dictionary items 

del person['name']
print(person)

# %%
employee = {
    'name':'Nishan',
    'skills':['Py','SQL'],
    'comtact':['mail#g',123456]

}
print(employee)

# %%
###
# conditional Statement:
#1.if -statement 
#evaluate the boolean expression that results in either True or False

#syntax:
#if boolean_expression:
    #//block of code 
 ###

# %%
total = float(input("enter the amount"))

if total > 500:
    print("congratulatrion you are alloted for the IRDS tax prize")
    
else:
    print("the total is less than 500")
# Out:
# the total is less than 500

# %%
#if -else block statement 
#if condition:
 #---

#else:
 #---block of code
 
 # --elif --for multiple conditions

# %%
marks = int(input("Enter the marks of any one subject: "))
if marks >= 80:
    print("Excellent")
elif marks >= 60:
    print("Good")
elif marks >= 40:
    print("Average")
else:
    print("Fail")
# Out:
# Fail

# %% [markdown]
# Approve a loan based on income greater than or equals to 50,000 and credit score greater than or equal to 700 .other wise reject it

# %%
income = 500000
credit_score = 700

if income >= 50000 and credit_score >= 700:
    print("Loan approved")
else:
    print("Loan rejected")
# Out:
# Loan approved

# %%
confidence = [0.95, 0.45,0.85, 0.33, 0.9]
if confidence[2]>=0.80 and confidence[4]<=0.85:
    print("accepted prediction")
else:
    print("send for the review")
# Out:
# send for the review

# %% [markdown]
# Write a program to determine if a given number is a muliple by 5
# output:multiple of 5

# %%
number = 5 
if number % 5 == 0:
    print("Multiple of 5")
else:
    print("Not a multiple of 5 ")
# Out:
# Multiple of 5

# %%
x_input = input("Enter a number: ").strip()
x = int(x_input) if x_input else 0
total = int(input("Enter the initial total: "))
if x!= 0:
    total += x # total = total + x 
    print("Total:", total)
else:
    print("No change in total.")
print("This statement is outside the if block and will always execute.")
# Out:
# Total: 2
# This statement is outside the if block and will always execute.

# %% [markdown]
# f -string -formatted string
# -easy and fast way to insert the variable and expression directly into s string in the python
# f "-string---{variable}"

# %%
name= "soni"
age = 22
#message =f "Hello,My name is {name} and my age is {age }"
print(f"Hello, my name is {name} and my age is {age}")
# Out:
# Hello, my name is soni and my age is 22

# %%
#write a Python program that checks if acharacter entered by the user is vowel or consonant.(we use in) in keyword 

alphabet = input("Enter a vowel  alphabet: ")
vowel  = []
if alphabet in ['a', 'e', 'i', 'o', 'u','A', 'E', 'I', 'O', 'U']:
    print("Vowel")
# elif alphabet in ('A', 'E', 'I', 'O', 'U'):
#         print("Vowel")
else:
    print("Consonant")
# Out:
# Consonant

# %%
ch = input ("Enter a Character:")
if ch.isupper():
    print("Uppercase letter")
elif ch.islower():
    print("Lowercase letter")

# %% [markdown]
# for loop:
# A for loop is used to iterate over elements in a sequence .
# -it runs a block of code repeatdely as long as the condition is  true
#
# syntax:
# for iterable_variable in variables:
# print()

# %%
#iterate over the string;
name="soni"
for i in name:
    print(i)
# Out:
# s
# o
# n
# i
