# %% [markdown]
# #1. Write a program that prints your favourite programming language. Add a single-line comment directly above the print statement explaining what that line does.
# #This line prints my favourite programming language.

# %%
# This line prints my favourite programming language.
print("Python")

# %% [markdown]
# #2. Write a program with three variables: name, age, and city. Add a short inline comment on the same line as each variable, explaining what it stores.

# %%
name = "priya"       # Stores the person's name
age = 22            # Stores the person's age
city = "Itahari"    # Stores the person's city

print(name)
print(age)
print(city)
age = 22            # Stores the person's age
city = "Itahari"    # Stores the person's city

print(name)
print(age)
print(city)

# %% [markdown]
# #3. Write a program that stores a number in a variable and prints it. Above the code, add a comment block (several # lines) describing the program's purpose, an author placeholder, and a date placeholder.

# %%
#Program: Display a Number
#Author: priya 
#Date: 2022-10-10

Number = 10
print("The value of Number is:", Number)

# %% [markdown]
# #4. Write a program that contains one line of code that should NOT run (turn it into a comment) followed by a line that prints "Task complete.

# %%
# print("This line should not run")

print("Task complete")
